# %%
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive/',force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
df=pd.read_csv("/content/gdrive/MyDrive/Econ 441B 23Winter/chord-progressions.csv")

# %%
df
# Out:
#    1st chord  2nd chord  3rd chord    4th chord  Progression Quality
# 6          4          1          5  Alternative                  NaN
# 4          4          1          5       Catchy                  NaN
# 1          1          1          1   Didgeridoo                  NaN
# 1          6          4          5     Dreadful                  NaN
# 1          6          2          5     Dreadful                  NaN
# 1          6          2          4      Endless                  NaN
# 1          3          4          6    Energetic                  NaN
# 1          5          1          4         Folk                  NaN
# 1          6          1          4         Folk                  NaN
# 6          5          4          3     Flamenco                  NaN
# 6          5          6          5     Flamenco                  NaN
# 1          4          3          6       Grunge                  NaN
# 2          5          1          6         Jazz                  NaN
# ...

# %%
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(df['1st chord'])
plt.title("1st chord count")
plt.xlabel("1st chord ID")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# ### The 1st chord ID 4 has most counts.
